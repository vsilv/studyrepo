# %% [markdown]
# 2.1 Physikalisches Pendel

# %%
l=95.4t10 = np.array([16.09,16.12,16.12,16.08,16.09,16.03])/10t20 = np.array([32.09,32.06,32.12,32.09,32.12,32.15])/20t=np.concatenate([t10,t20])

# %%
# Out:
# ((array([1, 0, 0, 0, 0, 1, 2, 0, 0, 2]),  array([ 1.603 ,  1.6039,  1.6048,  1.6057,  1.6066,  1.6075,  1.6084,        1.6093,  1.6102,  1.6111,  1.612 ]),  <a list of 10 Patch objects>), (array([1, 0, 0, 2, 0, 0, 2, 0, 0, 1]),  array([ 1.603  ,  1.60345,  1.6039 ,  1.60435,  1.6048 ,  1.60525,        1.6057 ,  1.60615,  1.6066 ,  1.60705,  1.6075 ]),  <a list of 10 Patch objects>))

# %% [markdown]
# 2.2 Mathematisches Pendel

# %% [markdown]
# 2.2.1 Abhängigkeit von der Pändellänge

# %%
l=np.array([96.00,71.30,63.40,53.60,42.10])t=np.array([19.59,17.03,16.09,14.75,13.15])scatter(t,l)plot(t,l)

# %% [markdown]
# 2.2.2 Bestimmung der Messgenauigkeit

# %%
l=59.7t=np.array([15.56,15.50,15.59,15.53,15.43,15.53,15.56,15.56])/10hist(t)
# Out:
# (array([1, 0, 0, 0, 1, 0, 2, 0, 3, 1]), array([ 1.543 ,  1.5446,  1.5462,  1.5478,  1.5494,  1.551 ,  1.5526,        1.5542,  1.5558,  1.5574,  1.559 ]), <a list of 10 Patch objects>)

# %% [markdown]
# 2.2.3 Amplitudenabhängigkeit
